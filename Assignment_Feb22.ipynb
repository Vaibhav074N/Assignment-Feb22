# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhav074N/Assignment-Feb22/blob/main/Assignment_Feb22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1.

# %%
import pandas as pd

# %%
obj = pd.Series([4, 8, 15, 16, 23, 42])

# %%
obj
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %% [markdown]
# Q2.

# %%
data = ['om','sai','prakesh','haari','dhrti',2,39,12,32,1]

# %%
pd.Series(['om','sai','prakesh','haari','dhrti',2,39,12,32,1])
# Out:
# 0         om
# 1        sai
# 2    prakesh
# 3      haari
# 4      dhrti
# 5          2
# 6         39
# 7         12
# 8         32
# 9          1
# dtype: object

# %% [markdown]
# Q3.

# %%
data = [{'Name':'Alice','Age':'25','Gender':'Female'},
        {'Name':'Bob','Age':'30','Gender':'Male'},
        {'Name':'Clarie','Age':'27','Gender':'Female'}]

# %%
frame = pd.DataFrame(data)

# %%
frame
# Out:
#      Name Age  Gender
# 0   Alice  25  Female
# 1     Bob  30    Male
# 2  Clarie  27  Female

# %% [markdown]
# Q4.What is ‘DataFrame’ in pandas and how is it different from pandas.series? Explain with an example.
#
# Ans:
#
# Pandas:
#        it contains data structures and data manipulation tools designed to make
#        data cleaning and data analysis, fast and easy in python.
#
# Series - it is a 1-D array like object containing a sequence and values.
#
# Dataframe - it represents a rectangular table of data and contains an ordered
#                        collection of columns,each of which can be different value type(numeric,string,boolean,etc).

# %%
# series
x = pd.Series([5,6,7])

# %%
x
# Out:
# 0    5
# 1    6
# 2    7
# dtype: int64

# %%
# dataframe
data = {"state":['nanded','ohio','ohio','ohio','nevada'],
        "year":[2004,2003,2002,2001,2000],
        "pop":[1.5,1.7,3.6,2.4,2.9]}

# %%
f = pd.DataFrame([data])

# %%
f
# Out:
#                                 state                            year  \
# 0  [nanded, ohio, ohio, ohio, nevada]  [2004, 2003, 2002, 2001, 2000]
#
#                          pop
# 0  [1.5, 1.7, 3.6, 2.4, 2.9]

# %% [markdown]
# Q5.What are some common functions you can use to manipulate data in a Pandas DataFrame? Can you give an example of when you might use one of these functions?

# %%
# head() = it returns first n rows from data
# tail() = it returns last n rows from data 

d = pd.read_csv('/content/services.csv')

# %%
d.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
d.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %% [markdown]
# Q6.Which of the following is mutable in nature Series, DataFrame, Panel?
#
# Ans:
#
# In Pandas, both Series and DataFrame are mutable, and panel is immutable.
# This means that you can modify the contents of a Series or DataFrame after it has been created. For example, you can add or remove rows or columns, update existing values, or perform calculations to create new columns based on existing data.

# %% [markdown]
# Q7.Create a DataFrame using multiple Series. Explain with an example.

# %%
a=pd.Series(['om','rucha','pryia','tom'])
b=pd.Series([8,6,7,5])
c=pd.Series([21,22,20,19])

# %%
d = {'Name':a,"Grade":b,"Age":c}

# %%
f = pd.DataFrame(d)

# %%
f
# Out:
#     Name  Grade  Age
# 0     om      8   21
# 1  rucha      6   22
# 2  pryia      7   20
# 3    tom      5   19
